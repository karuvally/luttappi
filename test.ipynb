# %%
# import essential stuff
from luttappi import *
from bokeh.plotting import show, output_notebook

# %%
# read from logs
data = read_log("26-11-18")

# %%
# format the data
temp_values = data["temp_values"]
time_values = data["time_values"]
x_values = [x for x in range(len(temp_values))]

# %%
# initialize the plot
plot = figure(
    title="Temperature History",
    x_axis_label="Time (HH:MM:SS)",
    y_axis_label="Temperature (C)"
)

# set the output to notebook
output_notebook()

# prepare line plot
plot.line(
    x=x_values, 
    y=temp_values,
    line_width=2
)

# label the X-axis points
x_axis_labels = {}
for i in range(len(x_values)):
    x_axis_labels.update({x_values[i]: time_values[i]})
    
# set the label for x-axis
plot.xaxis.major_label_overrides = x_axis_labels

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2973">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d32cad7f-8e0f-4b93-bddc-9cc1cc7be0f1"></div>
